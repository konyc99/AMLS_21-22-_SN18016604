# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import regularizers, optimizers
import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv('dataset/image/label.csv',dtype=str)
df_test=pd.read_csv('dataset/test/label_test2.csv',dtype=str)

# %%
datagen=ImageDataGenerator(rescale=1./255.,validation_split=0.20)
train_generator=datagen.flow_from_dataframe(
dataframe=df,
directory="dataset/image/",
x_col="file_name",
y_col="label",
subset="training",
batch_size=30,
seed=67,
shuffle=True,
#classes= ['No Tumor','Tumor'],
class_mode="categorical",
target_size=(256,256),
color_mode = "grayscale")

validation_generator=datagen.flow_from_dataframe(
dataframe=df,
directory="dataset/image/",
x_col="file_name",
y_col="label",
subset="validation",
batch_size=30,
seed=67,
shuffle=True,
class_mode="categorical",
#classes= ['No Tumor','Tumor'],
target_size=(256,256),
color_mode = "grayscale")

datagen=ImageDataGenerator(rescale=1./255.)

test=datagen.flow_from_dataframe(
dataframe=df_test,
directory="dataset/test/",
x_col="file_name",
y_col=None,
batch_size=30,
seed=67,
shuffle=False,
class_mode=None,
#classes= ['No Tumor','Tumor'],
target_size=(256,256),
color_mode = "grayscale" )
# Out:
# Found 2392 validated image filenames belonging to 4 classes.
# Found 598 validated image filenames belonging to 4 classes.
# Found 10 validated image filenames.

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding='same',
                 input_shape=(256,256,1)))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 256, 256, 32)      320
# _________________________________________________________________
# activation (Activation)      (None, 256, 256, 32)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 254, 254, 32)      9248
# _________________________________________________________________
# activation_1 (Activation)    (None, 254, 254, 32)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 127, 127, 32)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 127, 127, 32)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 127, 127, 64)      18496
# _________________________________________________________________
# activation_2 (Activation)    (None, 127, 127, 64)      0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 125, 125, 64)      36928
# _________________________________________________________________
# activation_3 (Activation)    (None, 125, 125, 64)      0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 62, 62, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 246016)            0
# _________________________________________________________________
# dense (Dense)                (None, 512)               125960704
# _________________________________________________________________
# activation_4 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 126,027,748
# Trainable params: 126,027,748
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
        x=train_generator,
        epochs=15,
        validation_data=validation_generator,
        validation_steps=None,
        validation_freq=1,
        max_queue_size=10,
        workers=1,

)

model.save("dataset/model_try.h5",overwrite=True,include_optimizer=True)  # always save your weights after training or during training
# Out:
# Epoch 1/15
# 80/80 [==============================] - 243s 3s/step - loss: 0.9217 - accuracy: 0.4615 - val_loss: 0.4249 - val_accuracy: 0.6037
# Epoch 2/15
# 80/80 [==============================] - 237s 3s/step - loss: 0.4015 - accuracy: 0.6342 - val_loss: 0.3129 - val_accuracy: 0.7709
# Epoch 3/15
# 80/80 [==============================] - 239s 3s/step - loss: 0.2697 - accuracy: 0.7747 - val_loss: 0.2193 - val_accuracy: 0.8478
# Epoch 4/15
# 80/80 [==============================] - 246s 3s/step - loss: 0.1603 - accuracy: 0.8842 - val_loss: 0.2057 - val_accuracy: 0.8512
# Epoch 5/15
# 80/80 [==============================] - 238s 3s/step - loss: 0.0906 - accuracy: 0.9415 - val_loss: 0.1911 - val_accuracy: 0.8880
# Epoch 6/15
# 80/80 [==============================] - 237s 3s/step - loss: 0.0579 - accuracy: 0.9670 - val_loss: 0.2324 - val_accuracy: 0.8813
# Epoch 7/15
# 80/80 [==============================] - 238s 3s/step - loss: 0.0335 - accuracy: 0.9849 - val_loss: 0.4096 - val_accuracy: 0.8378
# Epoch 8/15
# 80/80 [==============================] - 238s 3s/step - loss: 0.0300 - accuracy: 0.9883 - val_loss: 0.2278 - val_accuracy: 0.8930
# Epoch 9/15
# 80/80 [==============================] - 235s 3s/step - loss: 0.0194 - accuracy: 0.9912 - val_loss: 0.2566 - val_accuracy: 0.8963
# Epoch 10/15
# 80/80 [==============================] - 236s 3s/step - loss: 0.0174 - accuracy: 0.9933 - val_loss: 0.3393 - val_accuracy: 0.8997
# Epoch 11/15
# 80/80 [==============================] - 233s 3s/step - loss: 0.0158 - accuracy: 0.9950 - val_loss: 0.2822 - val_accuracy: 0.9080
# Epoch 12/15
# 80/80 [==============================] - 230s 3s/step - loss: 0.0117 - accuracy: 0.9958 - val_loss: 0.3608 - val_accuracy: 0.8946
# Epoch 13/15
# 80/80 [==============================] - 234s 3s/step - loss: 0.0109 - accuracy: 0.9971 - val_loss: 0.3169 - val_accuracy: 0.8946
# Epoch 14/15
# 80/80 [==============================] - 238s 3s/step - loss: 0.0153 - accuracy: 0.9954 - val_loss: 0.3368 - val_accuracy: 0.8846
# Epoch 15/15
# 80/80 [==============================] - 241s 3s/step - loss: 0.0097 - accuracy: 0.9962 - val_loss: 0.3070 - val_accuracy: 0.8946

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(20,10))
plt.grid()
plt.show()

# %%
model.evaluate(
    x=validation_generator,
    steps = 19
)
# Out:
# 19/19 [==============================] - 8s 398ms/step - loss: 0.3026 - accuracy: 0.8930
# [0.3026498556137085, 0.8929824829101562]

# %%
test_generator = test

#test_generator.reset()
pred=model.predict(test_generator,verbose=1)

print("predictions shape:", pred.shape)
# Out:
# 1/1 [==============================] - 0s 483ms/step
# predictions shape: (10, 4)

# %%
print(pred)
predicted_class_indices=np.argmax(pred,axis=1)
# Out:
# [[1.3022947e-11 1.0000000e+00 5.6339319e-11 3.5581867e-11]
#  [1.0661977e-14 3.8080751e-15 1.7624892e-14 1.0000000e+00]
#  [6.2882195e-12 3.7286348e-11 2.3491433e-13 1.0000000e+00]
#  [1.0375255e-15 7.9537097e-12 3.8906598e-13 1.0000000e+00]
#  [1.0000000e+00 2.5093297e-18 7.8198715e-21 4.4323019e-21]
#  [3.2144285e-06 6.5320613e-08 9.9999666e-01 8.8245400e-15]
#  [8.3984393e-01 1.6015610e-01 3.8171144e-08 9.7767716e-10]
#  [1.0000000e+00 2.7238782e-14 5.1117519e-15 5.0726054e-17]
#  [9.9999642e-01 2.2950187e-06 6.5859686e-11 1.2796040e-06]
#  [9.1905616e-02 1.1570325e-01 9.3861144e-07 7.9239023e-01]]

# %%
print(pred)
# Out:
# [[1.3022947e-11 1.0000000e+00 5.6339319e-11 3.5581867e-11]
#  [1.0661977e-14 3.8080751e-15 1.7624892e-14 1.0000000e+00]
#  [6.2882195e-12 3.7286348e-11 2.3491433e-13 1.0000000e+00]
#  [1.0375255e-15 7.9537097e-12 3.8906598e-13 1.0000000e+00]
#  [1.0000000e+00 2.5093297e-18 7.8198715e-21 4.4323019e-21]
#  [3.2144285e-06 6.5320613e-08 9.9999666e-01 8.8245400e-15]
#  [8.3984393e-01 1.6015610e-01 3.8171144e-08 9.7767716e-10]
#  [1.0000000e+00 2.7238782e-14 5.1117519e-15 5.0726054e-17]
#  [9.9999642e-01 2.2950187e-06 6.5859686e-11 1.2796040e-06]
#  [9.1905616e-02 1.1570325e-01 9.3861144e-07 7.9239023e-01]]

# %%
labels = (train_generator.class_indices)
labels = dict((v,k) for k,v in labels.items())
predictions = [labels[k] for k in predicted_class_indices]

# %%
filenames=test_generator.filenames
filenames=filenames[:480]
results=pd.DataFrame({"Filename":filenames,
                      "Predictions":predictions})
#results.to_csv("results.csv",index=False)
print(filenames)
print(len(predictions))
print(results)
# Out:
# ['IMAGE_2990.jpg', 'IMAGE_2991.jpg', 'IMAGE_2992.jpg', 'IMAGE_2993.jpg', 'IMAGE_2994.jpg', 'IMAGE_2995.jpg', 'IMAGE_2996.jpg', 'IMAGE_2997.jpg', 'IMAGE_2998.jpg', 'IMAGE_2999.jpg']
# 10
#          Filename       Predictions
# 0  IMAGE_2990.jpg  meningioma_tumor
# 1  IMAGE_2991.jpg   pituitary_tumor
# 2  IMAGE_2992.jpg   pituitary_tumor
# 3  IMAGE_2993.jpg   pituitary_tumor
# 4  IMAGE_2994.jpg      glioma_tumor
# 5  IMAGE_2995.jpg          no_tumor
# 6  IMAGE_2996.jpg      glioma_tumor
# 7  IMAGE_2997.jpg      glioma_tumor
# 8  IMAGE_2998.jpg      glioma_tumor
# 9  IMAGE_2999.jpg   pituitary_tumor

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
from IPython.display import display


import pandas as pd
import numpy as np

from PIL import Image

def get_img(filename, directory="dataset/test/"):
    
    file_path = os.path.join(directory, filename)
    img = Image.open(file_path)
    return np.array(img)

plt.imshow(get_img(filenames[5]))
plt.show()

# %%
IMAGE_2990.jpg	meningioma_tumor
IMAGE_2991.jpg	pituitary_tumor
IMAGE_2992.jpg	pituitary_tumor
IMAGE_2993.jpg	pituitary_tumor
IMAGE_2994.jpg	glioma_tumor
IMAGE_2995.jpg	no_tumor
IMAGE_2996.jpg	meningioma_tumor
IMAGE_2997.jpg	glioma_tumor
IMAGE_2998.jpg	glioma_tumor
IMAGE_2999.jpg	pituitary_tumor
